# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
income = pd.read_csv("Income.csv",index_col=0)

# %%
income.head()
# Out:
#    Education     Income
# 1  10.000000  26.658839
# 2  10.401338  27.306435
# 3  10.842809  22.132410
# 4  11.244147  21.169841
# 5  11.645485  15.192634

# %%
X = income["Education"] #input
y = income["Income"]  # output

# %%
X_r = X.values.reshape(-1,1)
y_r = y.values.reshape(-1,1)

# %%
#Grafik ---> Linear Regression 
plt.figure(figsize=(10,6))
plt.scatter(X,y)
#regresyon Doğrusu 
lr =LinearRegression()
lr.fit(X_r,y_r)
y_pred = lr.predict(X_r)
plt.plot(X,y_pred,color="red")

plt.xlabel("Education")
plt.ylabel("Income")
plt.title("Education-Income")
# Out:
# Text(0.5, 1.0, 'Education-Income')

# %%
#Tahmin DOğruluğu mu ? - model sadeliği mi ?
#Kısıtlayıcı olan modeller daha analaşılırdır
#Eğer ana amacımız Tahmin değil de çıkarım  yapmak ise  o zaman daha anlaşılır bir model seçebiliriz

# %%
#Regression :
#Sayısal değişkenlerin tahmini  için kurduğumuz modellere denir 
#örneğin yarın ki hisse senedi kaç tl olacak  gibi

# %%
#Sınıflandırma (Classification):
#Katagorik değişkenin hangi katagoriye yani sınıfa girdiğini bulma çabasına sınıflandırma denir.
