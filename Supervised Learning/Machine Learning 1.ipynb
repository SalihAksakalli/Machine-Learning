# %%
#Supervised Learning
#Gözetimli öğrenmede ne oldukları net olarak verilmiş girdiler kullanarak bir çıktı elde etmeye çalışırız
#Burada girdilerin aslında hangi çıktıya ait oldugu başta verilmiştir.
#Bilmediğimiz ise yeni bir girdi geldiğinde onun çıktısının ne olacağıdır 
#İşte bunu  tahminlemek için elimizdeki girdi - çıktı ilişkisine bakrız

# %%
#UnSupervised Learning
#Gözetimsiz öğrenmede elimizde girdiler vardır ancak çıktılar yoktur.
#Bu sebeple çıktıyı tahmin etmeye açlışmak olanaksızdır.
#Bunun yerine girdiler arasındaki ilişkiye odaklanırız
#böylece hangi girdinin  hangi çıktıyla alakalı oldugunu  anlarız

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Wage.csv")

# %%
df.describe() # Prints only numerical results to the screen
# Out:
#           Unnamed: 0         year          age      logwage         wage
# count    3000.000000  3000.000000  3000.000000  3000.000000  3000.000000
# mean   218883.373000  2005.791000    42.414667     4.653905   111.703608
# std    145654.072587     2.026167    11.542406     0.351753    41.728595
# min      7373.000000  2003.000000    18.000000     3.000000    20.085537
# 25%     85622.250000  2004.000000    33.750000     4.447158    85.383940
# 50%    228799.500000  2006.000000    42.000000     4.653213   104.921507
# 75%    374759.500000  2008.000000    51.000000     4.857332   128.680488
# max    453870.000000  2009.000000    80.000000     5.763128   318.342430

# %%
df.head(10)
# Out:
#    Unnamed: 0  year  age      sex            maritl      race  \
# 0      231655  2006   18  1. Male  1. Never Married  1. White
# 1       86582  2004   24  1. Male  1. Never Married  1. White
# 2      161300  2003   45  1. Male        2. Married  1. White
# 3      155159  2003   43  1. Male        2. Married  3. Asian
# 4       11443  2005   50  1. Male       4. Divorced  1. White
# 5      376662  2008   54  1. Male        2. Married  1. White
# 6      450601  2009   44  1. Male        2. Married  4. Other
# 7      377954  2008   30  1. Male  1. Never Married  3. Asian
# 8      228963  2006   41  1. Male  1. Never Married  2. Black
# 9       81404  2004   52  1. Male        2. Married  1. White
#
#          education              region        jobclass          health  \
# 0     1. < HS Grad  2. Middle Atlantic   1. Industrial       1. <=Good
# 1  4. College Grad  2. Middle Atlantic  2. Information  2. >=Very Good
# 2  3. Some College  2. Middle Atlantic   1. Industrial       1. <=Good
# 3  4. College Grad  2. Middle Atlantic  2. Information  2. >=Very Good
# 4       2. HS Grad  2. Middle Atlantic  2. Information       1. <=Good
# 5  4. College Grad  2. Middle Atlantic  2. Information  2. >=Very Good
# 6  3. Some College  2. Middle Atlantic   1. Industrial  2. >=Very Good
# 7  3. Some College  2. Middle Atlantic  2. Information       1. <=Good
# 8  3. Some College  2. Middle Atlantic  2. Information  2. >=Very Good
# 9       2. HS Grad  2. Middle Atlantic  2. Information  2. >=Very Good
#
#   health_ins   logwage        wage
# 0      2. No  4.318063   75.043154
# 1      2. No  4.255273   70.476020
# 2     1. Yes  4.875061  130.982177
# 3     1. Yes  5.041393  154.685293
# 4     1. Yes  4.318063   75.043154
# 5     1. Yes  4.845098  127.115744
# 6     1. Yes  5.133021  169.528538
# 7     1. Yes  4.716003  111.720849
# 8     1. Yes  4.778151  118.884359
# 9     1. Yes  4.857332  128.680488

# %%
df1 = df[["age","wage"]]
#girdi->input, Feature --> X
X = df1["age"]
#Çıktı-> outputlabel-> y
y = df1["wage"]

#ortalama Hesaplama 
y_mean = df1.groupby("age").mean()
#Grafiği hazırla
fig,ax = plt.subplots(figsize=(8,8))
#detayı çiz
ax.scatter(X,y,color= "orange")
#ortalamayı Çiz
ax.plot(y_mean.index,y_mean)
#grafiği formatla

plt.title("wage-Age")
plt.xlabel("Age")
plt.ylabel("wage")
plt.show()

# %%
df2 = df[["year","wage"]]
X= df2["year"]
y= df2["wage"]
y_mean = df2.groupby("year").mean()
fig,ax = plt.subplots(figsize=(8,8))
ax.scatter(X,y,color="orange")
ax.plot(y_mean.index,y_mean,color="red")
plt.title("wage-year")
plt.xlabel("year")
plt.ylabel("wage")
plt.show()

# %%
df3 = df[["education","wage"]]
X  = df3["education"]
y = df3["wage"]
y_grouped = df3.groupby("education")
y_grouped.boxplot(subplots=False,figsize=(8,8),rot=90)
# Out:
# <Axes: >
